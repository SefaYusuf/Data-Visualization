# %% [markdown]
# ## Import library

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Saeborn icindeki data setleri

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
tips["day"].unique()   # benzersiz ifadeleri getirir
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# ![image%20%282%29.png](attachment:image%20%282%29.png)

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip");

# %%
# sns.regplot(tips.total_bill, tips.tip);

# %%
sns.regplot(data = tips, x = "total_bill", y = "tip");

# %%
sns.regplot(data=tips, x="total_bill", y="tip", x_estimator = np.mean,ci=67);

# %% [markdown]
# ## Figsize

# %%
plt.figure(figsize = (10,5))

sns.scatterplot(x = tips["total_bill"], y = tips["tip"]);

# %% [markdown]
# ## Hue

# %%
plt.figure(figsize = (10,5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips , hue = "sex");

# %%
plt.figure(figsize = (10,5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips , hue = "day");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "smoker");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "smoker" , hue= "sex");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "smoker" , hue= "day");

# %%
# %matplotlib notebook

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "smoker" , hue= "day");
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib inline

# %% [markdown]
# ## OOM (Object Oriented Method)

# %%
fig, ax = plt.subplots(1, 2, figsize =  (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", ax = ax[0]);
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", ax = ax[1]);

# %% [markdown]
# ## Renk

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", palette = "plasma");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", alpha = 0.4);

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", alpha = 0.6, style = "sex", palette = "plasma");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day", alpha = 0.6, s = 100);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data= tips, x = "total_bill", y = "tip", hue ="day", style = "sex", palette = "cubehelix", alpha = 0.7, s = 100);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data= tips, x = "total_bill", y = "tip", hue ="sex", style = "day",size = "smoker",  alpha = 0.7);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data= tips, x = "total_bill", y = "tip", hue ="sex", size = "smoker", alpha = 0.7);

# %% [markdown]
# ## Distribution Plot

# %%
sns.displot(data = tips, x = "total_bill");

# %%
sns.displot(data = tips, x = "total_bill", bins = 50);

# %%
sns.displot(data = tips, x = "total_bill", bins = 50, kde = True);

# %%
sns.displot(data = tips, x = "total_bill", kde = True);
